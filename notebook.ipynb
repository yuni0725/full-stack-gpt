# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 12
#       6 llm = HuggingFaceHub(
#       7     repo_id="mistralai/Mistral-7B-Instruct-v0.1",
#       8 )
#      10 chain = prompt | llm
# ---> 12 chain.invoke({
#      13     "word": "kiwi"
#      14 })
#
# File c:\Users\권남윤\OneDrive\바탕 화면\full-stack-gpt\env\Lib\site-packages\langchain\schema\runnable\base.py:1213, in RunnableSequence.invoke(self, input, config)
#    1211 try:
#    1212     for i, step in enumerate(self.steps):
# -> 1213         input = step.invoke(
#    1214             input,
#    1215             # mark each step as a child run
#    1216             patch_config(
#    1217                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    1218             ),
#    1219         )
#    1220 # finish the root run
#    1221 except BaseException as e:
#
# ...
